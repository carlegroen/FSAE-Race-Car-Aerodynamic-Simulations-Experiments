# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import seaborn as sb
sb.set_style('whitegrid')
sb.set_palette('deep')

#stack measures:
mesh_size = ([6.36*100000, 1.03*1000000, 3.87*1000000,22.8*1000000])
DF  = ([123.1, 123.13, 125.12,126.2])

#figure
#plot(meshsize_downforce(1,:),meshsize_downforce(2,:),'ro')
#xlabel('Mesh size [Number of cells]')
#ylabel('Downforce')

plt.figure(figsize=(10, 7.5))  
ax = plt.subplot(111)    
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.plot(mesh_size, DF, 'o-', label = '$u_\infty$ = $20$ ms$^{-1}$', lw=2) 
#cl40 = plt.plot(AOAsweep, CL40, label = '$u_\infty$ = $40$ ms$^{-1}$', lw=2) 

#cltheory = plt.plot(AOA-35, CLTheory, label = '$C_{L_{theory}}$', lw=2) 
plt.legend(loc=3,fontsize=14, bbox_to_anchor=(0., 1.02, 1., .102), ncol=3, mode='expand')

#plt.yticks(range(0, 2.5, 10), fontsize=14)    
plt.xticks(fontsize=14) 
plt.xlabel('Mesh size $[Number of cells]$', fontsize=14)
plt.ylabel('Downforce $[N]$', fontsize=14)
plt.ticklabel_format(axis='x', style='sci', scilimits=(1,2))



plt.savefig('../../report/figures/DFprmeshsize.png', bbox_inches='tight')
